# %% [markdown]
# <a href="https://colab.research.google.com/github/Kiwiabacaxi/Python_Canopy/blob/main/BSTree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import from visual_bst to show only the visual part of the BST
from google.colab import files
import visual_package
